# %%
# !pip install pylabel
import logging
logging.getLogger().setLevel(logging.CRITICAL)

# %%
from pylabel import importer

# %%
#Specify path to the coco.json file
path_to_annotations = r"C:\Users\USER\Downloads\trainval\annotations\bbox-annotations.json"
#Specify the path to the images (if they are in a different folder than the annotations)
path_to_images = r"C:\Users\USER\Downloads\trainval\images"

#Import the dataset into the pylable schema 
dataset = importer.ImportCoco(path_to_annotations, path_to_images=path_to_images, name="trainval")
dataset.df.head(5)
# Out:
#                                  img_folder         img_filename img_path  \
# id
# 0   C:\Users\USER\Downloads\trainval\images  image_000000001.jpg
# 1   C:\Users\USER\Downloads\trainval\images  image_000000001.jpg
# 2   C:\Users\USER\Downloads\trainval\images  image_000000001.jpg
# 3   C:\Users\USER\Downloads\trainval\images  image_000000001.jpg
# 4   C:\Users\USER\Downloads\trainval\images  image_000000002.jpg
#
#     img_id  img_width  img_height img_depth ann_segmented  ann_bbox_xmin  \
# id
# 0        0       1024         768                                    846
# 1        0       1024         768                                    848
# 2        0       1024         768                                     74
# 3        0       1024         768                                    153
# 4        1       1024         576                                    488
#
#     ann_bbox_ymin  ...  ann_segmentation  ann_iscrowd  ann_pose  \
# id                 ...
# ...

# %%
print(f"Number of images: {dataset.analyze.num_images}")
print(f"Number of classes: {dataset.analyze.num_classes}")
print(f"Classes:{dataset.analyze.classes}")
print(f"Class counts:\n{dataset.analyze.class_counts}")
print(f"Path to annotations:\n{dataset.path_to_annotations}")
# Out:
# Number of images: 2239
# Number of classes: 2
# Classes:['person', 'car']
# Class counts:
# person    10800
# car        5972
# Name: cat_name, dtype: int64
# Path to annotations:
# C:\Users\USER\Downloads\trainval\annotations

# %%
from IPython.display import Image, display
display(dataset.visualize.ShowBoundingBoxes(5))
display(dataset.visualize.ShowBoundingBoxes("image_000000005.jpg"))
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x25E086E15B0>
# <PIL.Image.Image image mode=RGB size=1024x926 at 0x25E09AE9940>

# %%
dataset.path_to_annotations = r"C:\Users\USER\Downloads\trainval\annotations/yolo"
dataset.export.ExportToYoloV5()[0]
# Out:
# 'training\\dataset.yaml'

# %% [raw]
# I have taken annotations of all images with pylabel importer
# and all annotatios are saved in in labels_edit folder in car_person.zip file
